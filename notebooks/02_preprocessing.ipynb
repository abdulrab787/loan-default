# %%
import sys
import os

# Add project root to Python path
sys.path.append(os.path.abspath(".."))

import pandas as pd
from src.preprocessing import fit_and_save_preprocessor

# %% [markdown]
# Load cleaned dataset

# %%
df = pd.read_csv("../data/accepted_with_default.csv", low_memory=False)
print(df.shape)
# Out:
# (2650550, 151)

# %% [markdown]
# Run preprocessing

# %%
preprocessor = fit_and_save_preprocessor(df, save_dir="../models")
print("Preprocessor fitted and saved successfully.")
# Out:
# c:\KC\loan-default\venv\Lib\site-packages\sklearn\impute\_base.py:641: UserWarning: Skipping features without any observed values: ['member_id']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(
# c:\KC\loan-default\venv\Lib\site-packages\sklearn\impute\_base.py:641: UserWarning: Skipping features without any observed values: ['member_id']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(
# Preprocessing complete and saved:
# - ../models/preprocessor.pkl
# - ../models/X_train_processed.pkl
# - ../models/X_val_processed.pkl
# - ../models/y_train.pkl
# - ../models/y_val.pkl
# Preprocessor fitted and saved successfully.
